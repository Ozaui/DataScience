# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
plt.scatter("Height", "Weight", data=df)
plt.title("Athlete Weight vs Height")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# # Seaborn

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("darkgrid")
sns.scatterplot(x="Height", y="Weight", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", hue="Sex", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
df["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", hue="Medal", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", hue="Sex", style="Medal", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", hue="Sex", style="Medal", size="Age", data= df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("whitegrid")
sns.lineplot(x="Height", y="Weight", hue="Sex", style="Medal", size="Age", data=df)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Athlettes Weight - Height")
plt.show()

# %%
sns.set_style("white")
sns.displot(x="Height", hue="Sex", data=df)
plt.xlabel("Height")
plt.ylabel("Frequency")
plt.title("Athletes Height Distribution")
plt.show()

# %%
sns.set_style("white")
sns.displot(x="Height", hue="Sex",kind="kde", data=df)
plt.xlabel("Height")
plt.ylabel("Frequency")
plt.title("Athletes Height Distribution")
plt.show()

# %%
sns.barplot(x="Medal", y="Height", hue="Sex", data=df)
plt.title("Medal by height")
plt.xlabel("Madel Count")
plt.ylabel("Height")
plt.show()

# %%
sns.catplot(x="Medal", y="Height", hue="Sex", col="Season", data=df)
plt.show()

# %%
sns.relplot(x="Medal", y="Height", hue="Sex", col="Season", data=df)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.003631 -0.011141 -0.009176  0.011885
# Age    -0.003631  1.000000  0.138246  0.212069 -0.115137
# Height -0.011141  0.138246  1.000000  0.796213  0.047578
# Weight -0.009176  0.212069  0.796213  1.000000  0.019095
# Year    0.011885 -0.115137  0.047578  0.019095  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
